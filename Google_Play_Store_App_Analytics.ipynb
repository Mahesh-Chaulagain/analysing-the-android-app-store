# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
# .sample(n) methods gives us n random rows
df_apps.sample(5)
# Out:
#                                  App         Category  Rating  Reviews  \
# 8497  Dinosaur Simulator: Dino World             GAME    4.00    26649
# 906                    Propel BI APP         BUSINESS    5.00        3
# 1073     Bx Thailand Alert (Bitcoin)          FINANCE    4.70        3
# 5674                   Insightly CRM         BUSINESS    3.80     1383
# 5928                ADWLauncher 1 EX  PERSONALIZATION    4.30    28728
#
#       Size_MBs   Installs  Type  Price Content_Rating           Genres  \
# 8497     66.00  5,000,000  Free      0           Teen           Action
# 906      23.00        100  Free      0       Everyone         Business
# 1073      8.20        100  Free      0       Everyone          Finance
# 5674     51.00    100,000  Free      0       Everyone         Business
# 5928      2.80    500,000  Paid  $2.49       Everyone  Personalization
#
#           Last_Updated Android_Ver
# 8497    August 5, 2018  4.2 and up
# 906      July 24, 2018  4.4 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated','Android_Ver'],axis=1,inplace=True)

# %%
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
# ...

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
# check for individual app by looking up the wntries with the name in the App column
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates()
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
# specify the subset to remove all the duplicates
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App','Type','Price'])
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
# find highest rated apps
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 1230         Sway Medical      MEDICAL    5.00        3     22.00      100
# 1227    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 1224       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
# sort apps based on size higher to lower
df_apps_clean.sort_values('Size_MBs',ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
# sort apps by number of reviews
df_apps_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# ...

# %%
sorted_df = df_apps_clean.sort_values(by=['Reviews'], ascending=False)
paid_apps_in_sorted_df = sorted_df[sorted_df['Type'] == 'Paid']
paid_apps_in_sorted_df.head(50)
# Out:
#                                                     App            Category  \
# 9220                                          Minecraft              FAMILY
# 8825                                      Hitman Sniper                GAME
# 7151                      Grand Theft Auto: San Andreas                GAME
# 7954                                        Bloons TD 5              FAMILY
# 7988                                  Where's My Water?              FAMILY
# 6746                         Card Wars - Adventure Time              FAMILY
# 7563                                         True Skate              SPORTS
# 7633                            Five Nights at Freddy's                GAME
# 6496                              Beautiful Widgets Pro     PERSONALIZATION
# 6594                                DraStic DS Emulator                GAME
# 7776                                Fruit Ninja Classic                GAME
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
# count the number of occurances of each rating with .value_counts()
ratings = df_apps_clean['Content_Rating'].value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
# create a pie chart using ploty
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# add a title and names for the pie chart
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title='Content Rating',
    names=ratings.index)
# traces refers to the graphical marks on figure
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create a donut by passing hole as a parameter
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title='Content Rating',
    names=ratings.index,
    hole=0.5)
# traces refers to the graphical marks on figure
fig.update_traces(textposition='outside', textinfo='percent+label', textfont_size=15)
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.sort_values('Installs',ascending=False).head()
# Out:
#                                                      App       Category  \
# 10731                                     My Talking Tom           GAME
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10711                         SHAREit - Transfer & Share          TOOLS
# 10713                      imo free video calls and chat  COMMUNICATION
# 10717                                                Pou           GAME
#
#        Rating   Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 10731    4.50  14891223     36.00  500,000,000  Free     0       Everyone
# 10746    4.70  24900999      3.40  500,000,000  Free     0       Everyone
# 10711    4.60   7790693     17.00  500,000,000  Free     0       Everyone
# 10713    4.30   4785892     11.00  500,000,000  Free     0       Everyone
# 10717    4.30  10485308     24.00  500,000,000  Free     0       Everyone
#
#               Genres
# 10731         Casual
# 10746          Tools
# ...

# %%
# to check the datatype either use .describe() on column or .info() on the dataframe
print(df_apps_clean.info())
df_apps_clean.Installs.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB
# None
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
# replace the comma(,) with an empty string
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',',"")
# convert the string data to number
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App','Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price.describe()
# Out:
# count     8199
# unique      73
# top          0
# freq      7595
# Name: Price, dtype: object

# %%
# convert the price to numeric data type
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$',"")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean.sort_values('Price',ascending=False).head(20)
# Out:
# <ipython-input-160-4930752b142b>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# remove apps that cost more than $250
df_apps_clean = df_apps_clean[df_apps_clean['Price']<250]
df_apps_clean.sort_values('Price', ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2463         PTA Content Master    MEDICAL    4.20       64     41.00
#
#       Installs  Type  Price Content_Rating     Genres
# 2281      1000  Paid  79.99       Everyone    Medical
# 1407       100  Paid  39.99       Everyone    Medical
# 2629      1000  Paid  37.99       Everyone  Lifestyle
# 2481      1000  Paid  33.99       Everyone    Medical
# 2463      1000  Paid  29.99       Everyone    Medical

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
# to work out the highest grossing paid apps multiply the value in the price and the installs column to get the number
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue_Estimate', ascending=False)[:10]
# Out:
# <ipython-input-162-c67cd27d1b46>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
# find the number of different categories
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
# calculate the number of apps per each category using the .value_counts()
top10 = df_apps_clean.Category.value_counts()
top10.head(10)
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(
    x=top10.index,  # index = category name
    y=top10.values
)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
# group all apps by category and sum the number of installations to get idea of how popular a category is
category_installs = df_apps_clean.groupby('Category').agg({'Installs':pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39162676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211677750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               692018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1134006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4437554490
# ...

# %%
# create a horizontal bar chart by adding the orientation parameter and titles
h_bar = px.bar(
    x=category_installs.Installs,
    y=category_installs.index,
    orientation='h',
    title='Category Popularity'
)
h_bar.update_layout(xaxis_title='Number of downloads',yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
# work out the number of apps in each category
cat_number = df_apps_clean.groupby('Category').agg({'App':pd.Series.count})
# use .merge() and combine the two dataframes
cat_merged_df =  pd.merge(cat_number,category_installs,on="Category",how="inner")
print(f'the dimensions of the dataframe are:{cat_merged_df.shape}')
cat_merged_df.sort_values('Installs',ascending=False)
cat_merged_df.head()
# Out:
# the dimensions of the dataframe are:(33, 2)
#                      App    Installs
# Category
# ART_AND_DESIGN        61   114233100
# AUTO_AND_VEHICLES     73    53129800
# BEAUTY                42    26916200
# BOOKS_AND_REFERENCE  169  1665791655
# BUSINESS             262   692018120

# %%
# create scatter chart
scatter = px.scatter(
    cat_merged_df, #data
    x='App', # column name
    y='Installs',
    title='Category concentration',
    size='App', # the size of the markers is determined by the 'App' column
    hover_name=cat_merged_df.index,
    color='Installs' # the color of the markers is determined by the 'Installs' column
)
scatter.update_layout(
    xaxis_title='Number of Apps (Lower = more concentrated)',
    yaxis_title='Installs',
    yaxis=dict(type='log')
    # This above line sets the y-axis scale to logarithmic. Using a logarithmic scale on the y-axis can be useful when dealing with data that
    # spans several orders of magnitude, such as 'Installs' in this case. It helps in visualizing and comparing data points across a wide range
    # of values more effectively.
)
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.columns
# check number of genres
df_apps_clean.Genres.nunique()
# Out:
# 114

# %%
# view multiple categories separated by ';'
df_apps_clean.Genres.value_counts().sort_values(ascending=True)[:5]
# Out:
# Lifestyle;Pretend Play      1
# Strategy;Education          1
# Adventure;Education         1
# Role Playing;Brain Games    1
# Tools;Education             1
# Name: Genres, dtype: int64

# %%
# Check how many different types of genres are there
# .explode(): Transforms each list of genres into separate rows, replicating the index values.
# This means that if a row had multiple genres separated by ';', it will be duplicated for each genre, maintaining other column values.
df_apps_clean['Genres'].str.split(';').explode().unique()
# Out:
# array(['Medical', 'Arcade', 'Sports', 'Business', 'Books & Reference',
#        'Social', 'Tools', 'Education', 'Communication', 'Entertainment',
#        'Productivity', 'Action', 'Simulation', 'Casual', 'Lifestyle',
#        'Racing', 'Dating', 'Events', 'Maps & Navigation', 'Shopping',
#        'Personalization', 'Parenting', 'Photography', 'Puzzle',
#        'Health & Fitness', 'Food & Drink', 'News & Magazines', 'Finance',
#        'Role Playing', 'Trivia', 'Travel & Local', 'Adventure',
#        'Auto & Vehicles', 'Art & Design', 'Educational', 'Board',
#        'Brain Games', 'Beauty', 'Video Players & Editors', 'Pretend Play',
#        'Casino', 'Comics', 'Action & Adventure', 'Word', 'Weather',
#        'Strategy', 'Card', 'Creativity', 'House & Home', 'Music',
#        'Music & Video', 'Libraries & Demo', 'Music & Audio'], dtype=object)

# %%
# Split the genres on the semi-colon and then stack them to get individual genre counts
df_apps_clean['Genres'].str.split(';').apply(pd.Series).stack().value_counts()
# or
df_apps_clean['Genres'].str.split(';').explode().value_counts()
# or
stack = df_apps_clean['Genres'].str.split(';', expand=True).stack()
print(f'Now we have a single column with shape:{stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres:{len(num_genres)}')
# Out:
# Now we have a single column with shape:(8564,)
# Number of genres:53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
num_genres
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Personalization            298
# Lifestyle                  298
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %%
bar = px.bar(
    num_genres,
    x=num_genres.index,
    y=num_genres.values,
    orientation='v',
    color=num_genres.values,
    title="Top Genre"
)
bar.update_layout(xaxis_title="Genre", yaxis_title="Apps Count")
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# working with color scales in plotly
bar = px.bar(
    x=num_genres.index[:15],
    y=num_genres.values[:15],
    title='Top Genres',
    hover_name=num_genres.index[:15],
    color=num_genres.values[:15],
    color_continuous_scale='Agsunset'
)
bar.update_layout(xaxis_title='Genre',
                  yaxis_title='Number of apps',
                  coloraxis_showscale=False
)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
# identify number of free and paid apps
df_apps_clean.Type.value_counts()
# Out:
# Free    7595
# Paid     589
# Name: Type, dtype: int64

# %%
# group data by category and then type
# the as_index=False push all the data into columns rather than end up with our Categories as index
df_free_vs_paid = df_apps_clean.groupby(['Category','Type'], as_index=False).agg({'App':pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
df_free_vs_paid.columns
# Out:
# Index(['Category', 'Type', 'App'], dtype='object')

# %% [markdown]
# bar**Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid.sort_values(by='App',ascending=False)
# Out:
#               Category  Type   App
# 19              FAMILY  Free  1456
# 25                GAME  Free   834
# 53               TOOLS  Free   656
# 21             FINANCE  Free   289
# 31           LIFESTYLE  Free   284
# ..                 ...   ...   ...
# 17       ENTERTAINMENT  Paid     2
# 24      FOOD_AND_DRINK  Paid     2
# 40           PARENTING  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 3    AUTO_AND_VEHICLES  Paid     1
#
# [61 rows x 3 columns]

# %%
# plot free vs paid apps per category
# to get a particular order, you can pass a dictonary to the axis parameter in .update_layout()
g_bar = px.bar(
    df_free_vs_paid,
    x='Category',
    y='App',
    title='Free vs Paid Apps by Category',
    color='Type', # Color of bars based on Type (free or paid)
    barmode='group' # Grouped bar mode
)
g_bar.update_layout(
    xaxis_title='Category',
    yaxis_title='Number of apps',
    xaxis={'categoryorder':'total descending'}, # Order categories based on total count descending
    yaxis=dict(type='log')
)
g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
# create box plots for Number of Installs
box = px.box(
    df_apps_clean,
    y='Installs',
    x='Type',
    color='Type',
    notched=True,
    points='all',
    title='How Many Downloads are Paid Apps Giving up?'
    )
box.update_layout(yaxis=dict(type='log'))
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
df_paid_apps
# Out:
#                                                     App   Category  Rating  \
# 28                                             Ra Ga Ba       GAME    5.00
# 47                                              Mu.F.O.       GAME    5.00
# 233              Chess of Blades (BL/Yaoi Game) (No VA)     FAMILY    4.80
# 248                                        The DG Buddy   BUSINESS    3.70
# 291                                 AC DC Power Monitor  LIFESTYLE    5.00
# ...                                                 ...        ...     ...
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...       GAME    4.40
# 7977                            Sleep as Android Unlock  LIFESTYLE    4.50
# 7988                                  Where's My Water?     FAMILY    4.70
# 8825                                      Hitman Sniper       GAME    4.60
# 9220                                          Minecraft     FAMILY    4.50
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# ...

# %%
box = px.box(
    df_paid_apps,
    x='Category',
    y='Revenue_Estimate',
    title='How much can Paid Apps Earn?'
)
box.update_layout(
    xaxis_title='Category',
    yaxis_title='Paid App Revenue',
    xaxis={'categoryorder':'min ascending'}, # order the categories on the x-axis based on the minimum value in ascending order
    yaxis=dict(type='log')
)
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
# calculate the median price
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
box = px.box(
    df_paid_apps,
    x='Category',
    y='Price',
    title='Price per Category'
)
box.update_layout(
    xaxis_title='Category',
    yaxis_title='Paid App Price',
    xaxis={'categoryorder':'max descending'},
    yaxis=dict(type='log')
)
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
